# %% [markdown]
# <div align=center>
#
# ---
# # **Hooke & Jeeves metrics comparison**
# ---
#
# </div>

# %%
import metrics
import phise

ctx = phise.examples.contexts.get_PHOB()
# ctx.camera.ideal = True
cache = metrics.generate_metrics_cache(ctx, N=1000)
df = metrics.build_summary_table(cache)
metrics.plot_null_depth_histograms(cache=cache)
metrics.plot_metric_evolution(cache=cache)
df
# Out:
#        Metric                                    Output 1  \
# 0  sum(N) / B   3.83e-03 ± 1.75e-03 | 1.58e-03 - 1.69e-02
# 1  max(N) / B   3.79e-03 ± 1.34e-03 | 1.67e-03 - 9.72e-03
# 2      sum(N)   3.89e-03 ± 1.73e-03 | 1.60e-03 - 1.30e-02
# 3      max(N)   3.78e-01 ± 1.06e+01 | 1.66e-03 - 3.35e+02
# 4        O3/B   2.02e-01 ± 2.47e+00 | 1.67e-03 - 5.62e+01
# 5          O3  6.85e+00 ± 2.65e+02 | -4.53e+03 - 7.01e+02
#
#                                       Output 2  \
# 0    3.93e-03 ± 1.73e-03 | 1.52e-03 - 1.31e-02
# 1    3.71e-03 ± 1.27e-03 | 1.59e-03 - 1.04e-02
# 2    3.82e-03 ± 1.75e-03 | 1.51e-03 - 1.34e-02
# 3    3.76e-01 ± 1.06e+01 | 1.65e-03 - 3.33e+02
# 4    8.49e-02 ± 3.59e-01 | 1.60e-03 - 8.54e+00
# 5  -5.27e+00 ± 5.21e+02 | -7.26e+03 - 3.20e+03
#
#                                      Output 3  \
# 0   2.94e-03 ± 1.00e-03 | 1.79e-03 - 1.12e-02
# 1   3.02e-03 ± 1.01e-03 | 1.91e-03 - 9.51e-03
# 2   2.91e-03 ± 9.95e-04 | 1.88e-03 - 1.14e-02
# 3   4.27e-02 ± 7.86e-01 | 1.82e-03 - 2.42e+01
# 4   2.78e-03 ± 5.97e-03 | 1.54e-03 - 1.48e-01
# 5  6.33e-03 ± 1.98e+00 | -4.89e+01 - 1.07e+01
#
#                                         Total
# 0   3.56e-03 ± 1.49e-03 | 1.52e-03 - 1.69e-02
# 1   3.51e-03 ± 1.21e-03 | 1.59e-03 - 1.04e-02
# 2   3.54e-03 ± 1.49e-03 | 1.51e-03 - 1.34e-02
# 3   2.66e-01 ± 7.32e+00 | 1.65e-03 - 3.35e+02
# 4   9.66e-02 ± 9.45e-01 | 1.54e-03 - 5.62e+01
# 5  5.30e-01 ± 2.63e+02 | -7.26e+03 - 3.20e+03

# %%
metrics.plot_cross_metric_final_distributions(ctx=ctx, cache=cache)
