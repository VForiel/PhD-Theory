# %% [markdown]
# <div align=center>
#
# ---
# # **Hooke & Jeeves metrics comparison**
# ---
#
# </div>

# %%
import numpy as np
import phise
import metrics
import matplotlib.pyplot as plt

# %% [markdown]
# # Metrics definition :
#
# Average depth
# $$
# \frac{\Sigma_i N_i}{B}
# $$
#
# Max depth
# $$
# \frac{\max_i N_i}{B}
# $$
#
# Average flux
# $$
# \Sigma_i N_i
# $$
#
# Max flux
# $$
# \max_i N_i
# $$

# %%
considered_metrics = {
    "sum(Ni)/B": metrics.average_depth,
    "max(Ni)/B": metrics.max_depth,
    "sum(Ni)": metrics.average_flux,
    # "max(Ni)": metrics.max_flux,
}

ctx = phise.examples.contexts.get_PHOB()
# ctx.camera.ideal = True

data = metrics.generate_data(ctx, metrics=considered_metrics, samples=1000)
# Out:
# Loading data from cache...

# %%
fig, axes, df = metrics.plot_final_metric_distributions(data, bins=60)
plt.show()
df
# Out:
#   calibration_metric evaluated_metric         mean         std  count
# 0          sum(Ni)/B        sum(Ni)/B     0.010443    0.003960   1000
# 1          max(Ni)/B        sum(Ni)/B     0.010480    0.004225   1000
# 2            sum(Ni)        sum(Ni)/B     0.010557    0.004036   1000
# 3          sum(Ni)/B        max(Ni)/B     0.006101    0.002336   1000
# 4          max(Ni)/B        max(Ni)/B     0.005809    0.002218   1000
# 5            sum(Ni)        max(Ni)/B     0.006040    0.002265   1000
# 6          sum(Ni)/B          sum(Ni)  1306.078340  510.657777   1000
# 7          max(Ni)/B          sum(Ni)  1309.087532  517.686923   1000
# 8            sum(Ni)          sum(Ni)  1276.757834  501.762602   1000

# %%
fig, axes, df = metrics.plot_final_null_depth_distributions(data, bins=60)
plt.show()
df
# Out:
#   calibration_metric  output_index      mean       std  count
# 0          sum(Ni)/B             0  0.004086  0.002780   1000
# 1          max(Ni)/B             0  0.003797  0.002562   1000
# 2            sum(Ni)             0  0.003987  0.002758   1000
# 3          sum(Ni)/B             1  0.004055  0.002754   1000
# 4          max(Ni)/B             1  0.004006  0.002545   1000
# 5            sum(Ni)             1  0.003921  0.002757   1000
# 6          sum(Ni)/B             2  0.002829  0.002113   1000
# 7          max(Ni)/B             2  0.003199  0.002192   1000
# 8            sum(Ni)             2  0.003043  0.002188   1000
