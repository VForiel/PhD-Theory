# %% [markdown]
# <div align=center>
#
# ---
# # Spectral response
# ---
#
# </div>

# %% [markdown]
# ## Wavelenght scan

# %%
import wavelength_scan

wavelength_scan.run(figsize=(4,3), n=21, save_as="generated/thesis/spectral")
# Out:
# ✅ Done.
